# %% [markdown]
# ![2023-03-05 10_47_07-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# https://cloud.google.com/dataflow/docs/guides/templates/provided-templates#cloudpubsubtobigquery

# %% [markdown]
# ## Zadanie 1. Utwórz zbiór danych i tabelę Cloud BigQuery

# %% [markdown]
# ![2023-03-05 11_14_27-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
bq mk taxirides

# %% [markdown]
# ![2023-04-30 15_57_26-Dashboard – qwiklabs-gcp-04-03b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 11_17_05-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# Cloud Shell

bq mk \
--time_partitioning_field timestamp \
--schema ride_id:string,point_idx:integer,latitude:float,longitude:float,\
timestamp:timestamp,meter_reading:float,meter_increment:float,ride_status:string,\
passenger_count:integer -t taxirides.realtime

# %% [markdown]
# ![2023-03-05 12_33_14-BigQuery – Empik Go – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-30 15_58_39-Dashboard – qwiklabs-gcp-04-03b… – Google Cloud console.png](data:image/png;base64,...)

# %%
# Konsola GCP wklejam schemat danych

ride_id:string,point_idx:integer,latitude:float,longitude:float,timestamp:timestamp,
meter_reading:float,meter_increment:float,ride_status:string,passenger_count:integer

# %% [markdown]
# ![2023-03-05 11_25_55-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
export BUCKET_NAME=exam-467473738737
gsutil mb gs://$BUCKET_NAME/

# %% [markdown]
# ![2023-04-30 16_00_49-Dashboard – qwiklabs-gcp-04-03b… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 11_40_44-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 2. Uruchom potok

# %% [markdown]
# ![2023-03-05 12_23_39-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# Temat Pub/Sub jest gdzieś w GCP, który działa non-stop z którego korzystam w tym zadaniu.
#
# W projekcie utworzyła się tylko subskrypcja.
#
# `projects/qwiklabs-gcp-04-03b947e2fb23/subscriptions/taxirides-realtime.subscription-1807618677852671467`

# %% [markdown]
# ![2023-04-30 16_15_34-taxirides-realtime.subscription-1807618677852671467 – Pub_Sub – qwiklabs-gcp-04-.png](data:image/png;base64,...)

# %%
projects/pubsub-public-data/topics/taxirides-realtime

# %% [markdown]
# ![2023-03-05 12_25_24-Zadania – Dataflow – Empik Go – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 12_42_16-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
empik-go:taxirides.realtime

# %% [markdown]
# ![2023-03-05 12_47_01-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gs://exam-46747373737/temp

# %% [markdown]
# ![2023-03-05 12_50_01-Tworzenie zadania na podstawie szablonu – Dataflow – Empik Go – Google Cloud Con.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 12_47_55-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 3. Wyślij zapytanie

# %% [markdown]
# ![2023-03-05 12_55_55-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
# %%bigquery
#
# SELECT
#   *
# FROM
#   `empik-go.taxirides.realtime`
# WHERE
#   DATE(timestamp) = "2023-03-05"
# LIMIT
#   1000

# %% [markdown]
# ![2023-03-05 12_56_57-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 15_18_16-Wyniki zapytania – BigQuery – Empik Go – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 15_19_41-BigQuery – Empik Go – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 4. Sprawdź swoją wiedzę

# %% [markdown]
# ![2023-03-05 12_59_27-Dataflow_ Qwik Start – szablony _ Google Cloud Skills Boost.png](data:image/png;base64,...)
