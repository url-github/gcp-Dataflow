# %% [markdown]
# ![2023-03-05 13_09_25-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 1. Tworzenie zasobnika Cloud Storage

# %% [markdown]
# ![2023-03-05 14_00_39-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 2. Instalowanie pip i pakietu SDK Cloud Dataflow

# %% [markdown]
# ![2023-03-05 14_05_09-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
docker run -it -e DEVSHELL_PROJECT_ID=$DEVSHELL_PROJECT_ID python:3.7 /bin/bash

# %% [markdown]
# ![2023-03-05 14_08_57-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
pip install 'apache-beam[gcp]'

# %% [markdown]
# ![2023-03-05 14_28_46-exam-57473833 – Szczegóły zasobnika – Cloud Storage – Empik Go – Google Cloud Co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 14_18_12-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
python -m apache_beam.examples.wordcount --output OUTPUT_FILE

# %% [markdown]
# ![2023-03-05 14_19_55-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
ls

# %% [markdown]
# ![2023-03-05 14_22_23-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 14_31_13-exam-57473833 – Szczegóły zasobnika – Cloud Storage – Empik Go – Google Cloud Co.png](data:image/png;base64,...)

# %%
cat OUTPUT_FILE-00000-of-00001

# %% [markdown]
# ![2023-03-05 14_23_25-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 14_32_04-exam-57473833 – Szczegóły zasobnika – Cloud Storage – Empik Go – Google Cloud Co.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 3. Zdalne uruchamianie przykładowego potoku

# %% [markdown]
# ![2023-03-05 14_24_57-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
BUCKET=gs://exam-687547838995 # nazwa zasobnika: exam-685848483

# %% [markdown]
# ![2023-03-05 14_33_38-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
python -m apache_beam.examples.wordcount --project $DEVSHELL_PROJECT_ID \
  --runner DataflowRunner \
  --staging_location $BUCKET/staging \
  --temp_location $BUCKET/temp \
  --output $BUCKET/results/output \
  --region us-west1

# %% [markdown]
# ![2023-03-05 14_37_26-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 4. Sprawdzanie, czy zadanie zakończyło się sukcesem

# %% [markdown]
# ![2023-03-05 14_46_49-Dataflow_ Qwik Start – Python _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 14_51_11-exam-57473833 – Szczegóły zasobnika – Cloud Storage – Empik Go – Google Cloud Co.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-03-05 14_50_48-https___ff012f4490a7025b3a590fb35e6d13a872aff12e2773dc6910b23c6-apidata.googleus.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 5. Sprawdź swoją wiedzę

# %% [markdown]
# ![2023-03-05 15_25_04-Przepływ danych_ Qwik Start – Python _ Zwiększenie umiejętności Google Cloud.png](data:image/png;base64,...)
